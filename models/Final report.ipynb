# %% [markdown]
# ## Notebook para expor os resultados obtidos nos modelos

# %% [markdown]
# ### Utilizando o dataset básico

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
# Score

scores = [0.19877966565152594, 0.4351074638820335, 0.35118008800150924, 0.3554738018906316, 0.29239877868113395]
labels = ['Decision Tree', 'Randon Forest', 'KNN', 'Gradient Boosting', 'Neural Network']

plt.bar(labels, scores)
plt.show()

# %%
# MAE

maes = [6.709194648478489, 5.207299418446191
, 5.695508336248105, 5.4271096191819765, 5.471818170168937]

plt.bar(labels, maes)
plt.show()

# %%
# Tempo de execução

tempos = [3.1769351959228516, 61.21118664741516, 10.763692140579224, 147.57860326766968, 352.91217947006226]

plt.bar(labels, tempos)
plt.show()
