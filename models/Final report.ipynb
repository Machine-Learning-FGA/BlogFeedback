# %% [markdown]
# ## Notebook para expor os resultados obtidos nos modelos

# %% [markdown]
# ### Utilizando o dataset básico

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
# Score

scores1 = [-0.19877966565152594, 0.4115205270844024, 0.35118008800150924, 0.3460346619431689, 0.2923987787450826]
labels = ['Decision Tree', 'Random Forest', 'KNN', 'Gradient Boosting', 'Neural Network']

plt.bar(labels, scores1)
plt.show()

# %%
# MAE

maes = [6.709194648478489, 5.358662032746896, 5.695508336248105, 5.441275539252392, 5.471818170168937]

plt.bar(labels, maes)
plt.show()

# %%
# Tempo de execução

tempos = [3.3465867042541504, 51.57696557044983, 10.146366596221924, 149.01269483566284, 167.82240676879883]

plt.bar(labels, tempos)
plt.show()

# %% [markdown]
# ### Utilizando o Extra Trees

# %%
# Score

scores2 = [-0.23784482075826904, 0.3724371027426182, 0.392903077237462, 0.43918818066166754, 0.3638774716551525]

plt.bar(labels, scores2)
plt.show()

# %%
# MAE

maes = [6.575424099335432, 5.4830849198021285, 5.3507345225603355, 5.133227818316951, 5.526729229758787]

plt.bar(labels, maes)
plt.show()

# %%
# Tempo de execução

tempos = [0.9665637016296387, 18.161784172058105, 6.459049224853516, 45.82485222816467, 172.41075801849365]

plt.bar(labels, tempos)
plt.show()

# %% [markdown]
# ### Utilizando o Train-frequent word

# %%
# Score

scores3 = [0.2847773076289901, 0.6320491997305041, 0.40382368912881295, 0.6345460597572365, 0.4806837426696884]

plt.bar(labels, scores3)
plt.show()

# %%
# MAE

maes = [0.4505532326568919, 0.3677170161815439, 0.4778244285265414, 0.37404617385937367, 0.4304705906735535]

plt.bar(labels, maes)
plt.show()

# %%
# Tempo de execução

tempos = [4.013042449951172, 264.2314279079437, 13.607582807540894, 52.85515570640564, 382.43728399276733]

plt.bar(labels, tempos)
plt.show()

# %% [markdown]
# ### Utilizando o Variance Threshold

# %%
# Score

scores4 = [-0.0964209705992296, 0.4308734371463302, 0.35112371914498, 0.43746200865963114, 0.4420412606078611]

plt.bar(labels, scores4)
plt.show()

# %%
# MAE

maes = [6.639932030758701, 5.322206537436039, 5.693001632272356, 5.2934621418295995, 4.744822915836197]

plt.bar(labels, maes)
plt.show()

# %%
# Tempo de execução

tempos = [1.3684475421905518, 22.507447719573975, 3.7540805339813232, 50.68832015991211, 34.811912059783936]

plt.bar(labels, tempos)
plt.show()

# %% [markdown]
# ### Média dos modelos

# %%
mDecision = (scores1[0] + scores2[0] + scores3[0] + scores4[0])/4
mRandom = (scores1[1] + scores2[1] + scores3[1] + scores4[1])/4
mKNN = (scores1[2] + scores2[2] + scores3[2] + scores4[2])/4
mGradient = (scores1[3] + scores2[3] + scores3[3] + scores4[3])/4
mNeural = (scores1[4] + scores2[4] + scores3[4] + scores4[4])/4

medias = [mDecision, mRandom, mKNN, mGradient, mNeural]
plt.bar(labels, medias)
plt.show()
