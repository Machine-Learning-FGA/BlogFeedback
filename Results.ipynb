# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Gradient Boosting Regressor

# %% [markdown]
# ### Score

# %%
preprocessing = ['Base dataset', 'Extra Trees', 'Train-frequent', 'V. Threshold']
score = [0.3554738018906316, 0.43918818066166754, 0.6347378170248149, 0.43672688837635776]

plt.bar(preprocessing, score)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# ### Execution Time

# %%
y = [147.57860326766968, 45.82485222816467, 45.28918409347534, 49.11903095245361]
x = [1,2,3,4]
plt.xticks(np.arange(5), ('0', 'Base dataset', 'Extra Trees', 'Train-frequent', 'V. Threshold'))
plt.plot(x,y)
plt.show()

# %% [markdown]
# # KNN Regressor

# %% [markdown]
# ### Score

# %%
preprocessing = ['Base dataset', 'Extra Trees', 'V. Threshold']
score = [0.35118008800150924, 0.8372053184122734, 0.564641324949096]

plt.bar(preprocessing, score)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# ### Execution Time

# %%
y = [10.763692140579224, 6.490399360656738, 3.977776527404785]
x = [1,2,3]
plt.xticks(np.arange(4), ('0', 'Base dataset', 'Extra Trees', 'V. Threshold'))
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Neural Network

# %% [markdown]
# ### Score

# %%
preprocessing = ['Base dataset', 'Extra Trees', 'Train-frequent', 'V. Threshold']
score = [0.29239877868113395, 0.31139127997764215, 0.9984246457286603, 0.3890900092766072]

plt.bar(preprocessing, score)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# ### Execution Time

# %%
y = [191.52566933631897, 99.35563802719116, 33.875277280807495, 161.30679440498352]
x = [1,2,3,4]
plt.xticks(np.arange(5), ('0', 'Base dataset', 'Extra Trees', 'Train-frequent', 'V. Threshold'))
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Random Forest

# %% [markdown]
# ### Score

# %%
preprocessing = ['Base dataset', 'Extra Trees', 'Train-frequent', 'V. Threshold']
score = [0.4351074638820335, 0.3724371027426182, 0.6320491997305041, 0.4106225952050914]

plt.bar(preprocessing, score)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# ### Execution Time

# %%
y = [61.21118664741516, 18.161784172058105, 295.0591003894806, 26.583113193511963]
x = [1,2,3,4]
plt.xticks(np.arange(5), ('0', 'Base dataset', 'Extra Trees', 'Train-frequent', 'V. Threshold'))
plt.plot(x,y)
plt.show()
